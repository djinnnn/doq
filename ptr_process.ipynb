# %%
import pandas as pd

file_path = [
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/443_ptr.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/784_ptr.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/853_ptr.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/8853_ptr.csv'
]

output_filepath = [
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/443_valid_ptr.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/784_valid_ptr.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/853_valid_ptr.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/8853_valid_ptr.csv'
]

#顺序为：443，784，853，8853
dfs = []

for file in file_path:
    df = pd.read_csv(file)
    dfs.append(df)

# %%
for df in dfs:
    count_not_exist = df['PTR'].str.contains('not exist', na=False).sum()
    print(f'The number of rows with "not exist" in the PTR column: {count_not_exist}')
    
    #df.to_csv('ptr.csv')
# Out:
# The number of rows with "not exist" in the PTR column: 22264
# The number of rows with "not exist" in the PTR column: 4
# The number of rows with "not exist" in the PTR column: 42
# The number of rows with "not exist" in the PTR column: 6

# %%
def check_valid_ptr_records(df):     
    df['First Octet'] = df['IP'].str.split('.').str[0]
    df['Last Octet'] = df['IP'].str.split('.').str[-1]

    df['Valid_PTR'] = df.apply(lambda row: (row['First Octet'] not in row['PTR'] and
                                        'resolution' not in row['PTR'] and
                                        row['Last Octet'] not in row['PTR']), axis=1)

# %%
for df in dfs:
    check_valid_ptr_records(df)

# %%
for df in dfs:
    print(df)
# Out:
#                     IP                                                PTR  \
# 0         23.51.141.19  ['a23-51-141-19.deploy.static.akamaitechnologi...
# 1         34.49.192.82         ['82.192.49.34.bc.googleusercontent.com.']
# 2        35.190.16.173        ['173.16.190.35.bc.googleusercontent.com.']
# 3       35.201.105.195       ['195.105.201.35.bc.googleusercontent.com.']
# 4          104.21.8.40  The DNS query name does not exist: 40.8.21.104...
# ...                ...                                                ...
# 159840   23.62.196.198  ['a23-62-196-198.deploy.static.akamaitechnolog...
# 159841    95.100.250.7  ['a95-100-250-7.deploy.static.akamaitechnologi...
# 159842    191.183.80.6                        ['bfb75006.virtua.com.br.']
# 159843   84.244.62.212  The DNS query name does not exist: 212.62.244....
# 159844     2.17.168.48  ['a2-17-168-48.deploy.static.akamaitechnologie...
#
#        First Octet Last Octet  Valid_PTR
# 0               23         19      False
# 1               34         82      False
# 2               35        173      False
# 3               35        195      False
# 4              104         40      False
# ...            ...        ...        ...
# 159840          23        198      False
# 159841          95          7      False
# 159842         191          6      False
# 159843          84        212      False
# 159844           2         48      False
#
# [159845 rows x 5 columns]
#                 IP                                                PTR  \
# 0   152.69.198.226  The DNS query name does not exist: 226.198.69....
# 1     67.48.195.77          ['syn-067-048-195-077.biz.spectrum.com.']
# 2     50.202.75.26  The DNS query name does not exist: 26.75.202.5...
# 3    69.135.114.87          ['syn-069-135-114-087.biz.spectrum.com.']
# 4      34.80.2.188          ['188.2.80.34.bc.googleusercontent.com.']
# 5     98.152.90.49          ['syn-098-152-090-049.biz.spectrum.com.']
# 6   108.197.32.180  ['108-197-32-180.lightspeed.sndgca.sbcglobal.n...
# 7   50.204.219.226  The DNS query name does not exist: 226.219.204...
# 8    67.48.192.207          ['syn-067-048-192-207.biz.spectrum.com.']
# 9    24.169.112.69          ['syn-024-169-112-069.biz.spectrum.com.']
# 10  24.169.113.211          ['syn-024-169-113-211.biz.spectrum.com.']
# 11  69.135.117.177          ['syn-069-135-117-177.biz.spectrum.com.']
# 12    67.48.193.75          ['syn-067-048-193-075.biz.spectrum.com.']
# 13  69.135.114.213          ['syn-069-135-114-213.biz.spectrum.com.']
# 14  174.99.252.195          ['syn-174-099-252-195.biz.spectrum.com.']
# 15   24.169.113.53          ['syn-024-169-113-053.biz.spectrum.com.']
# 16  202.61.228.255                                ['Trip-Gaming.de.']
# 17  144.22.142.187  The DNS query name does not exist: 187.142.22....
# 18   91.218.228.45                               ['mail.irubaev.ru.']
#
#    First Octet Last Octet  Valid_PTR
# 0          152        226      False
# 1           67         77      False
# 2           50         26      False
# 3           69         87      False
# 4           34        188      False
# 5           98         49      False
# 6          108        180      False
# 7           50        226      False
# 8           67        207      False
# 9           24         69      False
# 10          24        211      False
# 11          69        177      False
# 12          67         75      False
# 13          69        213      False
# 14         174        195      False
# 15          24         53      False
# 16         202        255       True
# 17         144        187      False
# 18          91         45       True
#                   IP                                                PTR  \
# 0       45.90.28.202                               ['dns1.nextdns.io.']
# 1        45.90.28.25                               ['dns1.nextdns.io.']
# 2      103.149.27.60  The DNS query name does not exist: 60.27.149.1...
# 3     103.139.181.21  The DNS query name does not exist: 21.181.139....
# 4       45.90.29.104  The DNS query name does not exist: 104.29.90.4...
# ..               ...                                                ...
# 157   195.254.166.86  The DNS query name does not exist: 86.166.254....
# 158   193.171.223.13                            ['u-13.vc-graz.ac.at.']
# 159  193.171.222.204                           ['t-204.vc-graz.ac.at.']
# 160    78.104.80.174                           ['n-174.vc-graz.ac.at.']
# 161     78.104.82.40                            ['p-40.vc-graz.ac.at.']
#
#     First Octet Last Octet  Valid_PTR
# 0            45        202       True
# 1            45         25       True
# 2           103         60      False
# 3           103         21      False
# 4            45        104      False
# ..          ...        ...        ...
# 157         195         86      False
# 158         193         13      False
# 159         193        204      False
# 160          78        174      False
# 161          78         40      False
#
# [162 rows x 5 columns]
#                  IP                                                PTR  \
# 0     213.35.96.241  The DNS query name does not exist: 241.96.35.2...
# 1      50.239.72.18  The DNS query name does not exist: 18.72.239.5...
# 2      69.4.234.146      ['asw-c16.r01.ord02.hostingservicesinc.net.']
# 3     50.168.72.116  ['c-50-168-72-116.unallocated.comcastbusiness....
# 4       72.17.92.75          ['syn-072-017-092-075.biz.spectrum.com.']
# 5     174.99.249.71          ['syn-174-099-249-071.biz.spectrum.com.']
# 6     69.135.112.63          ['syn-069-135-112-063.biz.spectrum.com.']
# 7     69.135.115.79          ['syn-069-135-115-079.biz.spectrum.com.']
# 8    69.135.116.165          ['syn-069-135-116-165.biz.spectrum.com.']
# 9      94.140.14.49                      ['94-140-14-49.adguard.com.']
# 10     185.242.4.34  The DNS query name does not exist: 34.4.242.18...
# 11     138.2.109.77  The DNS query name does not exist: 77.109.2.13...
# 12    38.46.219.165  The DNS query name does not exist: 165.219.46....
# 13    67.48.196.149          ['syn-067-048-196-149.biz.spectrum.com.']
# 14  141.145.220.240  The DNS query name does not exist: 240.220.145...
#
#    First Octet Last Octet  Valid_PTR
# 0          213        241      False
# 1           50         18      False
# 2           69        146       True
# 3           50        116      False
# 4           72         75      False
# 5          174         71      False
# 6           69         63      False
# 7           69         79      False
# 8           69        165      False
# 9           94         49      False
# 10         185         34      False
# 11         138         77      False
# 12          38        165      False
# 13          67        149      False
# 14         141        240      False

# %%
'''
def save_valid_ptrs:
    valid_ptr_df = df.loc[df['Valid_PTR'] == True, ['IP', 'PTR']]
    print(valid_ptr_df)
    valid_ptr_df.to_csv('valid_ptr_records.csv', index=False)
    print("已保存Valid_PTR为True的数据到 'valid_ptr_records.csv'")
'''
import numpy as np

def save_valid_ptrs(df, output_filename='valid_ptr_records.csv'):
    # 复制 DataFrame 防止修改原始数据
    df_copy = df.copy()
    
    # 找出 Valid_PTR 为 False 的行
    mask = df_copy['Valid_PTR'] == False
    
    # 如果 Valid_PTR 为 False，则将 PTR 列设置为 IP 列的值
    df_copy.loc[mask, 'PTR'] = df_copy.loc[mask, 'IP']
    
    # 将这些行的 Valid_PTR 设置为 True
    df_copy.loc[mask, 'Valid_PTR'] = True
    
    # 筛选出 Valid_PTR 为 True 的记录
    valid_ptr_df = df_copy[df_copy['Valid_PTR'] == True][['IP', 'PTR']]
    
    # 打印出有效的 PTR 记录，用于验证或调试
    print(valid_ptr_df)
    
    # 将这些记录保存到 CSV 文件
    valid_ptr_df.to_csv(output_filename, index=False)
    
    # 打印一个确认消息
    print(f"已保存Valid_PTR为True的数据到 '{output_filename}'")


# 示例使用方法
# df = pd.read_csv('your_input_file.csv')  # 假设你已经加载了一个包含 'Valid_PTR', 'IP', 'PTR' 列的 DataFrame
# save_valid_ptrs(df, 'custom_filename.csv')  # 调用函数并指定输出文件名

# %%
for i in range(4):
    save_valid_ptrs(dfs[i], output_filepath[i])
# Out:
#                     IP             PTR
# 0         23.51.141.19    23.51.141.19
# 1         34.49.192.82    34.49.192.82
# 2        35.190.16.173   35.190.16.173
# 3       35.201.105.195  35.201.105.195
# 4          104.21.8.40     104.21.8.40
# ...                ...             ...
# 159840   23.62.196.198   23.62.196.198
# 159841    95.100.250.7    95.100.250.7
# 159842    191.183.80.6    191.183.80.6
# 159843   84.244.62.212   84.244.62.212
# 159844     2.17.168.48     2.17.168.48
#
# [159845 rows x 2 columns]
# 已保存Valid_PTR为True的数据到 '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/443_valid_ptr.csv'
#                 IP                   PTR
# 0   152.69.198.226        152.69.198.226
# 1     67.48.195.77          67.48.195.77
# 2     50.202.75.26          50.202.75.26
# 3    69.135.114.87         69.135.114.87
# 4      34.80.2.188           34.80.2.188
# 5     98.152.90.49          98.152.90.49
# 6   108.197.32.180        108.197.32.180
# 7   50.204.219.226        50.204.219.226
# 8    67.48.192.207         67.48.192.207
# 9    24.169.112.69         24.169.112.69
# 10  24.169.113.211        24.169.113.211
# 11  69.135.117.177        69.135.117.177
# 12    67.48.193.75          67.48.193.75
# 13  69.135.114.213        69.135.114.213
# 14  174.99.252.195        174.99.252.195
# 15   24.169.113.53         24.169.113.53
# 16  202.61.228.255   ['Trip-Gaming.de.']
# 17  144.22.142.187        144.22.142.187
# 18   91.218.228.45  ['mail.irubaev.ru.']
# 已保存Valid_PTR为True的数据到 '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/784_valid_ptr.csv'
#                   IP                   PTR
# 0       45.90.28.202  ['dns1.nextdns.io.']
# 1        45.90.28.25  ['dns1.nextdns.io.']
# 2      103.149.27.60         103.149.27.60
# 3     103.139.181.21        103.139.181.21
# 4       45.90.29.104          45.90.29.104
# ..               ...                   ...
# 157   195.254.166.86        195.254.166.86
# 158   193.171.223.13        193.171.223.13
# 159  193.171.222.204       193.171.222.204
# 160    78.104.80.174         78.104.80.174
# 161     78.104.82.40          78.104.82.40
#
# [162 rows x 2 columns]
# 已保存Valid_PTR为True的数据到 '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/853_valid_ptr.csv'
#                  IP                                            PTR
# 0     213.35.96.241                                  213.35.96.241
# 1      50.239.72.18                                   50.239.72.18
# 2      69.4.234.146  ['asw-c16.r01.ord02.hostingservicesinc.net.']
# 3     50.168.72.116                                  50.168.72.116
# 4       72.17.92.75                                    72.17.92.75
# 5     174.99.249.71                                  174.99.249.71
# 6     69.135.112.63                                  69.135.112.63
# 7     69.135.115.79                                  69.135.115.79
# 8    69.135.116.165                                 69.135.116.165
# 9      94.140.14.49                                   94.140.14.49
# 10     185.242.4.34                                   185.242.4.34
# 11     138.2.109.77                                   138.2.109.77
# 12    38.46.219.165                                  38.46.219.165
# 13    67.48.196.149                                  67.48.196.149
# 14  141.145.220.240                                141.145.220.240
# 已保存Valid_PTR为True的数据到 '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/8853_valid_ptr.csv'
