# %%
import pandas as pd

file_path = [
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/443_ptr.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/784_ptr.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/853_ptr.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/8853_ptr.csv'
]

output_filepath = [
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/443.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/784.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/853.csv',
    '/home/ubuntu/wy/Projects/DoQ/data/20240505/ptr_results/8853.csv'
]

#顺序为：443，784，853，8853
dfs = []

for file in file_path:
    df = pd.read_csv(file)
    dfs.append(df)

# %%
for df in dfs:
    count_not_exist = df['PTR'].str.contains('not exist', na=False).sum()
    print(f'The number of rows with "not exist" in the PTR column: {count_not_exist}')
    
    #df.to_csv('ptr.csv')
# Out:
# The number of rows with "not exist" in the PTR column: 0
# The number of rows with "not exist" in the PTR column: 0
# The number of rows with "not exist" in the PTR column: 0
# The number of rows with "not exist" in the PTR column: 0

# %%
def check_valid_ptr_records(df):     
    df['First Octet'] = df['IP'].str.split('.').str[0]
    df['Last Octet'] = df['IP'].str.split('.').str[-1]

    df['Valid_PTR'] = df.apply(lambda row: (row['First Octet'] not in row['PTR'] and
                                        'resolution' not in row['PTR'] and
                                        row['Last Octet'] not in row['PTR'] and
                                        'Resolver' not in row['PTR']), axis=1)

# %%
for df in dfs:
    check_valid_ptr_records(df)

# %%
for df in dfs:
    print(df)
# Out:
#                     IP                                           PTR  \
# 0        39.136.147.25  'Resolver' object has no attribute 'resolve'
# 1        23.197.54.181  'Resolver' object has no attribute 'resolve'
# 2        3.163.230.128  'Resolver' object has no attribute 'resolve'
# 3       104.16.191.156  'Resolver' object has no attribute 'resolve'
# 4          34.36.71.58  'Resolver' object has no attribute 'resolve'
# ...                ...                                           ...
# 116392   23.200.29.105  'Resolver' object has no attribute 'resolve'
# 116393   102.66.240.53  'Resolver' object has no attribute 'resolve'
# 116394   52.84.132.121  'Resolver' object has no attribute 'resolve'
# 116395   23.220.26.236  'Resolver' object has no attribute 'resolve'
# 116396  34.172.135.225  'Resolver' object has no attribute 'resolve'
#
#        First Octet Last Octet  Valid_PTR
# 0               39         25      False
# 1               23        181      False
# 2                3        128      False
# 3              104        156      False
# 4               34         58      False
# ...            ...        ...        ...
# 116392          23        105      False
# 116393         102         53      False
# 116394          52        121      False
# 116395          23        236      False
# 116396          34        225      False
#
# [116397 rows x 5 columns]
#                  IP                                           PTR First Octet  \
# 0    43.143.233.189  'Resolver' object has no attribute 'resolve'          43
# 1    131.186.62.203  'Resolver' object has no attribute 'resolve'         131
# 2     50.175.212.76  'Resolver' object has no attribute 'resolve'          50
# 3      45.91.92.121  'Resolver' object has no attribute 'resolve'          45
# 4     67.48.196.243  'Resolver' object has no attribute 'resolve'          67
# 5     67.48.196.207  'Resolver' object has no attribute 'resolve'          67
# 6     69.135.113.83  'Resolver' object has no attribute 'resolve'          69
# 7    24.169.112.137  'Resolver' object has no attribute 'resolve'          24
# 8     69.135.116.63  'Resolver' object has no attribute 'resolve'          69
# 9     67.48.196.199  'Resolver' object has no attribute 'resolve'          67
# 10    50.174.145.10  'Resolver' object has no attribute 'resolve'          50
# 11    69.135.112.33  'Resolver' object has no attribute 'resolve'          69
# 12   69.135.113.195  'Resolver' object has no attribute 'resolve'          69
# 13  172.245.187.107  'Resolver' object has no attribute 'resolve'         172
# 14   69.135.113.105  'Resolver' object has no attribute 'resolve'          69
# 15    158.220.84.25  'Resolver' object has no attribute 'resolve'         158
# 16        69.57.3.5  'Resolver' object has no attribute 'resolve'          69
# 17   69.135.115.109  'Resolver' object has no attribute 'resolve'          69
# 18   103.247.29.188  'Resolver' object has no attribute 'resolve'         103
#
#    Last Octet  Valid_PTR
# 0         189      False
# 1         203      False
# 2          76      False
# 3         121      False
# 4         243      False
# 5         207      False
# 6          83      False
# 7         137      False
# 8          63      False
# 9         199      False
# 10         10      False
# 11         33      False
# 12        195      False
# 13        107      False
# 14        105      False
# 15         25      False
# 16          5      False
# 17        109      False
# 18        188      False
#                   IP                                           PTR  \
# 0       45.90.28.254  'Resolver' object has no attribute 'resolve'
# 1     175.178.80.157  'Resolver' object has no attribute 'resolve'
# 2       45.90.31.211  'Resolver' object has no attribute 'resolve'
# 3       45.90.31.250  'Resolver' object has no attribute 'resolve'
# 4       45.90.31.253  'Resolver' object has no attribute 'resolve'
# ..               ...                                           ...
# 193   144.24.153.213  'Resolver' object has no attribute 'resolve'
# 194  157.100.230.148  'Resolver' object has no attribute 'resolve'
# 195   103.139.181.41  'Resolver' object has no attribute 'resolve'
# 196  103.139.181.122  'Resolver' object has no attribute 'resolve'
# 197  103.139.181.175  'Resolver' object has no attribute 'resolve'
#
#     First Octet Last Octet  Valid_PTR
# 0            45        254      False
# 1           175        157      False
# 2            45        211      False
# 3            45        250      False
# 4            45        253      False
# ..          ...        ...        ...
# 193         144        213      False
# 194         157        148      False
# 195         103         41      False
# 196         103        122      False
# 197         103        175      False
#
# [198 rows x 5 columns]
#                  IP                                           PTR First Octet  \
# 0     98.152.91.117  'Resolver' object has no attribute 'resolve'          98
# 1   142.171.224.177  'Resolver' object has no attribute 'resolve'         142
# 2     67.48.194.135  'Resolver' object has no attribute 'resolve'          67
# 3     54.95.143.212  'Resolver' object has no attribute 'resolve'          54
# 4    69.135.118.143  'Resolver' object has no attribute 'resolve'          69
# 5     98.152.88.209  'Resolver' object has no attribute 'resolve'          98
# 6    50.168.163.177  'Resolver' object has no attribute 'resolve'          50
# 7    50.168.163.181  'Resolver' object has no attribute 'resolve'          50
# 8     50.174.145.11  'Resolver' object has no attribute 'resolve'          50
# 9     69.135.117.83  'Resolver' object has no attribute 'resolve'          69
# 10   50.168.163.178  'Resolver' object has no attribute 'resolve'          50
# 11     72.17.92.187  'Resolver' object has no attribute 'resolve'          72
# 12    18.136.194.53  'Resolver' object has no attribute 'resolve'          18
# 13    174.99.249.75  'Resolver' object has no attribute 'resolve'         174
# 14   24.169.115.211  'Resolver' object has no attribute 'resolve'          24
# 15     72.17.92.171  'Resolver' object has no attribute 'resolve'          72
# 16     85.175.98.82  'Resolver' object has no attribute 'resolve'          85
# 17     98.152.91.71  'Resolver' object has no attribute 'resolve'          98
# 18    69.135.116.63  'Resolver' object has no attribute 'resolve'          69
# 19   24.169.114.161  'Resolver' object has no attribute 'resolve'          24
# 20    67.48.196.191  'Resolver' object has no attribute 'resolve'          67
# 21    69.135.118.65  'Resolver' object has no attribute 'resolve'          69
# 22     52.220.28.50  'Resolver' object has no attribute 'resolve'          52
# 23      78.47.222.7  'Resolver' object has no attribute 'resolve'          78
# 24     72.17.92.199  'Resolver' object has no attribute 'resolve'          72
#
#    Last Octet  Valid_PTR
# 0         117      False
# 1         177      False
# 2         135      False
# 3         212      False
# 4         143      False
# 5         209      False
# 6         177      False
# 7         181      False
# 8          11      False
# 9          83      False
# 10        178      False
# 11        187      False
# 12         53      False
# 13         75      False
# 14        211      False
# 15        171      False
# 16         82      False
# 17         71      False
# 18         63      False
# 19        161      False
# 20        191      False
# 21         65      False
# 22         50      False
# 23          7      False
# 24        199      False

# %%
'''
def save_valid_ptrs:
    valid_ptr_df = df.loc[df['Valid_PTR'] == True, ['IP', 'PTR']]
    print(valid_ptr_df)
    valid_ptr_df.to_csv('valid_ptr_records.csv', index=False)
    print("已保存Valid_PTR为True的数据到 'valid_ptr_records.csv'")
'''
import numpy as np

def save_valid_ptrs(df, output_filename='valid_ptr_records.csv'):
    # 复制 DataFrame 防止修改原始数据
    df_copy = df.copy()
    
   # 如果 Valid_PTR 为 False，则将 PTR 列设置为 IP 列的值
    df_copy['PTR'] = np.where(
    df_copy['Valid_PTR'] == False,
    df_copy['IP'],
    df_copy['PTR'].apply(lambda x: x.strip("[]'").split(',')[0].strip())
)

    
   # 将 PTR 列中的列表转换为字符串
    df_copy['PTR'] = df_copy['PTR'].apply(lambda x: x[0] if isinstance(x, list) else str(x))
   
   # 将这些行的 Valid_PTR 设置为 True
    df_copy['Valid_PTR'] = np.where(df_copy['Valid_PTR'] == False, True, df_copy['Valid_PTR'])
    
    # 筛选出 Valid_PTR 为 True 的记录
    valid_ptr_df = df_copy[df_copy['Valid_PTR'] == True][['IP', 'PTR']]
    
    # 打印出有效的 PTR 记录，用于验证或调试
    print(valid_ptr_df)
    
    # 将这些记录保存到 CSV 文件
    valid_ptr_df.to_csv(output_filename, index=False, header=False)
    
    # 打印一个确认消息
    print(f"已保存Valid_PTR为True的数据到 '{output_filename}'")


# 示例使用方法
# df = pd.read_csv('your_input_file.csv')  # 假设你已经加载了一个包含 'Valid_PTR', 'IP', 'PTR' 列的 DataFrame
# save_valid_ptrs(df, 'custom_filename.csv')  # 调用函数并指定输出文件名

# %%
for i in range(4):
    save_valid_ptrs(dfs[i], output_filepath[i])
# Out:
#                     IP             PTR
# 0        39.136.147.25   39.136.147.25
# 1        23.197.54.181   23.197.54.181
# 2        3.163.230.128   3.163.230.128
